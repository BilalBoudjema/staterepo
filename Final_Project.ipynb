# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

import scipy.stats

import io

import pandas as pd
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df=pd.read_csv(boston_url)

# %%
boston_df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO  LSTAT  MEDV
# ...

# %%
## For the "Median value of owner-occupied homes" provide a boxplot

ax = sns.boxplot(x='MEDV',data=boston_df)

plt.title('Median value of owner occupied homes')
plt.show()

# %%
## Provide a  bar plot for the Charles river variable graphe 
ax = sns.barplot(y='CHAS',data=boston_df)
plt.title('Median value of owner occupied homes')
plt.show()

# %%
## Boxplot for the MEDV variable vs the AGE variable. (devise the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older)

boston_df.loc[(boston_df['AGE'] <= 35), 'age_group'] = '35 years and younger'
boston_df.loc[(boston_df['AGE'] > 35)&(boston_df['AGE'] < 70), 'age_group'] = 'between 40 and 57 years'
boston_df.loc[(boston_df['AGE'] >= 70), 'age_group'] = '70 years and older'

ax = sns.boxplot(x= 'age_group', y='MEDV',data=boston_df)

plt.title('MEDV variable vs the AGE variable')
plt.ylabel('MEDV')
plt.xlabel('age_group')
plt.show()
# Out:
# C:\Users\Bilal\AppData\Local\Temp\ipykernel_16320\3139585857.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '35 years and younger' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   boston_df.loc[(boston_df['AGE'] <= 35), 'age_group'] = '35 years and younger'

# %%
## Acatter plot to show the relationship between nitric oxide concentrations and the proportion of non-retail business acres per town.

ax = sns.scatterplot(x= 'NOX', y='INDUS',data=boston_df)

plt.title('relationship between NOX variable and INDUS')
plt.ylabel('INDUS')
plt.xlabel('NOX')
plt.show()

# %%
## A Histogram for the pupil to teacher ratio variable

sns.set(rc={'figure.figsize':(25,8.30)})
sns.catplot(y='PTRATIO', kind='count', data=boston_df,)

plt.title('Create a histogram for the pupil to teacher ratio variable')
plt.xlabel('PTRATIO')

plt.show()

# %%
## Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)
## H0: µ_1=µ_2(There is no signifant differences in median value of houses bounded by the Charles river or not
## H1: µ_1≠µ_2(There is signifant differences in median value of houses bounded by the Charles river or not
## Use α = 0.05

ax = sns.distplot(boston_df['MEDV'],
                  bins=20,
                  kde=True,
                  color='red',
                  hist_kws={"linewidth": 15,'alpha':0.5})
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
## we can say it is normal on this sitation
# Out:
# C:\Users\Bilal\AppData\Local\Temp\ipykernel_16320\1429272957.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(boston_df['MEDV'],
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'Frequency')]

# %%
## Using the Levene's Test in Python to check test significance
scipy.stats.levene(boston_df[boston_df['CHAS'] == 1]['MEDV'],
                   boston_df[boston_df['CHAS'] == 0]['MEDV'], center='mean')
# since the p-value is not greater than 0.05 we can say inequality of variance
# Out:
# LeveneResult(statistic=8.75190489604598, pvalue=0.003238119367639829)

# %%
scipy.stats.ttest_ind(boston_df[boston_df['CHAS'] == 1]['MEDV'],
                   boston_df[boston_df['CHAS'] == 0]['MEDV'], equal_var = True)
# Out:
# TtestResult(statistic=3.996437466090509, pvalue=7.390623170519905e-05, df=504.0)

# %% [markdown]
#  # **Conclusion:** Since the p-value is less than alpha value 0.05, we reject the null hypothesis as there is enough proof that there is a significant difference in median value of houses bounded by the Charles river or not

# %%
boston_df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
# ...

# %%
## Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)


boston_df.loc[(boston_df['AGE'] <= 35), 'age_group'] = '35 years and younger'
boston_df.loc[(boston_df['AGE'] > 35)&(boston_df['AGE'] < 70), 'age_group'] = 'between 40 and 70 years'
boston_df.loc[(boston_df['AGE'] >= 70), 'age_group'] = '70 years and older'

# %%
scipy.stats.levene(boston_df[boston_df['age_group'] == '35 years and younger']['MEDV'],
                   boston_df[boston_df['age_group'] == 'between 40 and 70 years']['MEDV'], 
                   boston_df[boston_df['age_group'] == '70 years and older']['MEDV'], 
                   center='mean')
# since the p-value is more than 0.05, the variance are equal, for the purposes of this exercise, we will move along
# Out:
# LeveneResult(statistic=2.7806200293748304, pvalue=0.06295337343259205)

# %%
thirtyfive_lower = boston_df[boston_df['age_group'] == '35 years and younger']['MEDV']
forty_seventy = boston_df[boston_df['age_group'] == 'between 40 and 70 years']['MEDV']
seventy_older = boston_df[boston_df['age_group'] == '70 years and older']['MEDV']

# %%
f_statistic, p_value = scipy.stats.f_oneway(thirtyfive_lower, forty_seventy, seventy_older)
print("F_Statistic: {0}, P-Value: {1}".format(f_statistic,p_value))
# Out:
# F_Statistic: 36.40764999196599, P-Value: 1.7105011022702984e-15

# %% [markdown]
# # Conclusion: Since the p-value is less than alpha value 0.05, we reject the null hypothesis as there is enough proof that at least one of the means differ

# %%
## Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)


ax = sns.scatterplot(x="NOX", y="INDUS", data=boston_df)
scipy.stats.pearsonr(boston_df['NOX'], boston_df['INDUS'])
# Out:
# PearsonRResult(statistic=0.7636514469209157, pvalue=7.91336106123623e-98)

# %% [markdown]
# ## Conclusion: Since the p-value (Sig. (2-tailed) < 0.05, we reject the Null hypothesis and conclude that there exists a relationship between beauty and teaching evaluation score.

# %%
## What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)

import statsmodels.api as sm

## X is the input variables (or independent variables)
X = boston_df['DIS']
## y is the target/dependent variable
y = boston_df['MEDV']
## add an intercept (beta_0) to our model
X = sm.add_constant(X) 

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Thu, 12 Oct 2023   Prob (F-statistic):           1.21e-08
# Time:                        15:22:35   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...

# %% [markdown]
# **Conclusion:** p < 0.05 there is evidence of correlation between DIS variable and MEDV Variables
